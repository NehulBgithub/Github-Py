# %% [markdown]
# ## Practice Exercise 1

# %% [markdown]
# This is the first exercise for Pandas. You are provided with 2 fictional dataframes based on Indian Premier League (IPL). The first dataframe contains the data for all the teams who participated in the year 2018. In the second dataframe, the data is for the year 2017.

# %%
# import the required libraries - numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# #### Data Dictionary
#
# -  Team: Team name
# -  Matches: Total number of matches played
# -  Won: Number of matches won
# -  Lost: Number of matches lost
# -  Tied': Number of matches tied
# -  N/R: Number of matches with no result
# -  NRR: Net run rate (Rate of scoring the runs)
# -  For: Sum of runs scored by the team against other teams
# -  Against: Sum of runs scored by the opposite playing teams

# %%
# ipl18 contains the data for 2018
ipl18 = pd.DataFrame({'Team': ['SRH', 'CSK', 'KKR', 'RR', 'MI', 'RCB', 'KXIP', 'DD'],
                         'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
                         'Won': [9, 9, 8, 7, 6, 6, 6, 5],
                         'Lost': [5, 5, 6, 7, 8, 8, 8, 9],
                         'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
                         'N/R': [0, 0, 0, 0, 0, 0, 0, 0],
                         'NRR': [0.284, 0.253, -0.070, -0.250, 0.317, 0.129, -0.502, -0.222],
                         'For': [2230, 2488, 2363, 2130, 2380, 2322, 2210, 2297],
                         'Against': [2193, 2433, 2425, 2141, 2282, 2383, 2259, 2304]},
                         index = range(1,9)
                    )

# %%
# print the entire dataframe to check the entries
import numpy as np
import pandas as pd
ipl18 = pd.DataFrame({'Team': ['SRH', 'CSK', 'KKR', 'RR', 'MI', 'RCB', 'KXIP', 'DD'],
                         'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
                         'Won': [9, 9, 8, 7, 6, 6, 6, 5],
                         'Lost': [5, 5, 6, 7, 8, 8, 8, 9],
                         'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
                         'N/R': [0, 0, 0, 0, 0, 0, 0, 0],
                         'NRR': [0.284, 0.253, -0.070, -0.250, 0.317, 0.129, -0.502, -0.222],
                         'For': [2230, 2488, 2363, 2130, 2380, 2322, 2210, 2297],
                         'Against': [2193, 2433, 2425, 2141, 2282, 2383, 2259, 2304]})
ipl18
# Out:
#    Team  Matches  Won  Lost  Tied  N/R    NRR   For  Against
# 0   SRH       14    9     5     0    0  0.284  2230     2193
# 1   CSK       14    9     5     0    0  0.253  2488     2433
# 2   KKR       14    8     6     0    0 -0.070  2363     2425
# 3    RR       14    7     7     0    0 -0.250  2130     2141
# 4    MI       14    6     8     0    0  0.317  2380     2282
# 5   RCB       14    6     8     0    0  0.129  2322     2383
# 6  KXIP       14    6     8     0    0 -0.502  2210     2259
# 7    DD       14    5     9     0    0 -0.222  2297     2304

# %%
# ipl17 contains the data for 2017
ipl17 = pd.DataFrame({'Team': ['MI', 'RPS', 'SRH', 'KKR', 'KXIP', 'DD', 'GL', 'RCB'],
                         'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
                         'Won': [10, 9, 8, 8, 7, 6, 4, 3],
                         'Lost': [4, 5, 5, 6, 7, 8, 10, 10],
                         'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
                         'N/R': [0, 0, 1, 0, 0, 0, 0, 1],
                         'NRR': [0.784, 0.176, 0.469, 0.641, 0.123, -0.512, -0.412, -1.299],
                         'For': [2407, 2180, 2221, 2329, 2207, 2219, 2406, 1845],
                         'Against': [2242, 2165, 2118, 2300, 2229, 2255, 2472, 2033]},
                                             )

# %%
# print the entire dataframe to check the entries
ipl17
# Out:
#    Team  Matches  Won  Lost  Tied  N/R    NRR   For  Against
# 0    MI       14   10     4     0    0  0.784  2407     2242
# 1   RPS       14    9     5     0    0  0.176  2180     2165
# 2   SRH       14    8     5     0    1  0.469  2221     2118
# 3   KKR       14    8     6     0    0  0.641  2329     2300
# 4  KXIP       14    7     7     0    0  0.123  2207     2229
# 5    DD       14    6     8     0    0 -0.512  2219     2255
# 6    GL       14    4    10     0    0 -0.412  2406     2472
# 7   RCB       14    3    10     0    1 -1.299  1845     2033

# %% [markdown]
#  As a part of this exercise, solve the questions that are provided below. There are few tasks that you will have to perform to be able to answer the questions.
#
# **Task 1**
#
# You have to create a new column '*Points*' in both the dataframes that stores the total points scored by each team. The following scoring system is used to calculate the points of a team:
# -  Win: 2 points
# -  Loss: 0 points
# -  Tie: 1 point
# -  N/R (no result): 1 point

# %%
import numpy as np
import pandas as pd

# DataFrame
ipl18 = pd.DataFrame({
    'Team': ['SRH', 'CSK', 'KKR', 'RR', 'MI', 'RCB', 'KXIP', 'DD'],
    'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
    'Won': [9, 9, 8, 7, 6, 6, 6, 5],
    'Lost': [5, 5, 6, 7, 8, 8, 8, 9],
    'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
    'N/R': [0, 0, 0, 0, 0, 0, 0, 0],
    'NRR': [0.284, 0.253, -0.070, -0.250, 0.317, 0.129, -0.502, -0.222],
    'For': [2230, 2488, 2363, 2130, 2380, 2322, 2210, 2297],
    'Against': [2193, 2433, 2425, 2141, 2282, 2383, 2259, 2304]
})

# Calculate points
ipl18['Points'] = ipl18['Won'] * 2 + ipl18['Tied'] * 1 + ipl18['N/R'] * 1

# Display the DataFrame
print(ipl18)
# Out:
#    Team  Matches  Won  Lost  Tied  N/R    NRR   For  Against  Points
# 0   SRH       14    9     5     0    0  0.284  2230     2193      18
# 1   CSK       14    9     5     0    0  0.253  2488     2433      18
# 2   KKR       14    8     6     0    0 -0.070  2363     2425      16
# 3    RR       14    7     7     0    0 -0.250  2130     2141      14
# 4    MI       14    6     8     0    0  0.317  2380     2282      12
# 5   RCB       14    6     8     0    0  0.129  2322     2383      12
# 6  KXIP       14    6     8     0    0 -0.502  2210     2259      12
# 7    DD       14    5     9     0    0 -0.222  2297     2304      10

# %%
# ipl17 contains the data for 2017
import numpy as np
import pandas as pd
ipl17 = pd.DataFrame({'Team': ['MI', 'RPS', 'SRH', 'KKR', 'KXIP', 'DD', 'GL', 'RCB'],
                         'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
                         'Won': [10, 9, 8, 8, 7, 6, 4, 3],
                         'Lost': [4, 5, 5, 6, 7, 8, 10, 10],
                         'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
                         'N/R': [0, 0, 1, 0, 0, 0, 0, 1],
                         'NRR': [0.784, 0.176, 0.469, 0.641, 0.123, -0.512, -0.412, -1.299],
                         'For': [2407, 2180, 2221, 2329, 2207, 2219, 2406, 1845],
                         'Against': [2242, 2165, 2118, 2300, 2229, 2255, 2472, 2033]})
ipl17["Points"]=ipl17["Won"]*2+ipl17["Tied"]*1+ipl17["N/R"]*1
ipl17
# Out:
#    Team  Matches  Won  Lost  Tied  N/R    NRR   For  Against  Points
# 0    MI       14   10     4     0    0  0.784  2407     2242      20
# 1   RPS       14    9     5     0    0  0.176  2180     2165      18
# 2   SRH       14    8     5     0    1  0.469  2221     2118      17
# 3   KKR       14    8     6     0    0  0.641  2329     2300      16
# 4  KXIP       14    7     7     0    0  0.123  2207     2229      14
# 5    DD       14    6     8     0    0 -0.512  2219     2255      12
# 6    GL       14    4    10     0    0 -0.412  2406     2472       8
# 7   RCB       14    3    10     0    1 -1.299  1845     2033       7

# %% [markdown]
# #### Q1: Extract Top Four Teams
# Which of the following commands can you use to extract the top 4 teams in the dataset ‘ipl18’ with just the ‘Team’ and ‘Points’ column?
#
#
# -  ipl18.loc [0:3, [‘Team’, ‘Points’]]
# -  ipl18.loc [1:4, [‘Team’, ‘Points’]]
# -  ipl18.loc [0:4, [‘Team’, ‘Points’]]
# -  ipl18.loc [1:3, [‘Team’, ‘Points’]]

# %%
# Type your code here
ipl18
# Out:
#    Team  Matches  Won  Lost  Tied  N/R    NRR   For  Against  Points
# 0   SRH       14    9     5     0    0  0.284  2230     2193      18
# 1   CSK       14    9     5     0    0  0.253  2488     2433      18
# 2   KKR       14    8     6     0    0 -0.070  2363     2425      16
# 3    RR       14    7     7     0    0 -0.250  2130     2141      14
# 4    MI       14    6     8     0    0  0.317  2380     2282      12
# 5   RCB       14    6     8     0    0  0.129  2322     2383      12
# 6  KXIP       14    6     8     0    0 -0.502  2210     2259      12
# 7    DD       14    5     9     0    0 -0.222  2297     2304      10

# %%
ipl18.loc[1:4, ['Team', 'Points']]
# Out:
#   Team  Points
# 1  CSK      18
# 2  KKR      16
# 3   RR      14
# 4   MI      12

# %% [markdown]
# #### Q2: Filtering based on conditions
# Suppose in ‘ipl18’, you want to filter out the teams that have an NRR greater than zero, and for which the ‘For’ score exceeds the ‘Against’ score, i.e. both the conditions should be satisfied. Which teams will be left after you perform the above filtration? (Run the commands on the Python Notebook provided, rather than performing a manual calculation)
#
# -  CSK, MI
# -  SRH, CSK, MI
# -  SRH, CSK, RCB
# -  SRH, CSK, MI, RCB

# %%
# Type your code here
ipl18_filtered = ipl18[(ipl18['NRR'] > 0) & (ipl18['For'] > ipl18['Against'])]
print(ipl18_filtered['Team'])
# Out:
# 0    SRH
# 1    CSK
# 4     MI
# Name: Team, dtype: object

# %%
ipl18.loc[(ipl18.NRR > 0) & (ipl18.For > ipl18.Against), ]
# Out:
#   Team  Matches  Won  Lost  Tied  N/R    NRR   For  Against  Points
# 0  SRH       14    9     5     0    0  0.284  2230     2193      18
# 1  CSK       14    9     5     0    0  0.253  2488     2433      18
# 4   MI       14    6     8     0    0  0.317  2380     2282      12

# %% [markdown]
# #### Q3: Operations on multiple dataframes
# If all the stats are taken for both ‘ipl17’ and ‘ipl18’, which team with its total points greater than 25 will have the highest win percentage?
#
# -  KKR
# -  CSK
# -  RPS
# -  SRH

# %%
# Type your code here
ipl17and18_merge=Points.merge(returns, on="Points")
ipl17and18_merge.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 # Type your code here
# ----> 2 ipl17and18_merge=Points.merge(returns, on="Points")
#       3 ipl17and18_merge.head()
#
# NameError: name 'Points' is not defined

# %%
import pandas as pd

# Data for IPL 2017
ipl17 = pd.DataFrame({
    'Team': ['MI', 'RPS', 'SRH', 'KKR', 'KXIP', 'DD', 'GL', 'RCB'],
    'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
    'Won': [10, 9, 8, 8, 7, 6, 4, 3],
    'Lost': [4, 5, 5, 6, 7, 8, 10, 10],
    'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
    'N/R': [0, 0, 1, 0, 0, 0, 0, 1],
    'NRR': [0.784, 0.176, 0.469, 0.641, 0.123, -0.512, -0.412, -1.299],
    'For': [2407, 2180, 2221, 2329, 2207, 2219, 2406, 1845],
    'Against': [2242, 2165, 2118, 2300, 2229, 2255, 2472, 2033]
})
ipl17['Points'] = ipl17['Won'] * 2 + ipl17['Tied'] * 1 + ipl17['N/R'] * 1

# Data for IPL 2018
ipl18 = pd.DataFrame({
    'Team': ['SRH', 'CSK', 'KKR', 'RR', 'MI', 'RCB', 'KXIP', 'DD'],
    'Matches': [14, 14, 14, 14, 14, 14, 14, 14],
    'Won': [9, 9, 8, 7, 6, 6, 6, 5],
    'Lost': [5, 5, 6, 7, 8, 8, 8, 9],
    'Tied': [0, 0, 0, 0, 0, 0, 0, 0],
    'N/R': [0, 0, 0, 0, 0, 0, 0, 0],
    'NRR': [0.284, 0.253, -0.070, -0.250, 0.317, 0.129, -0.502, -0.222],
    'For': [2230, 2488, 2363, 2130, 2380, 2322, 2210, 2297],
    'Against': [2193, 2433, 2425, 2141, 2282, 2383, 2259, 2304]
})
ipl18['Points'] = ipl18['Won'] * 2 + ipl18['Tied'] * 1 + ipl18['N/R'] * 1

# Merge the dataframes on 'Team'
combined = pd.merge(ipl17, ipl18, on='Team', suffixes=('_17', '_18'))

# Calculate total points
combined['Total_Points'] = combined['Points_17'] + combined['Points_18']

# Filter teams with total points greater than 25
filtered = combined[combined['Total_Points'] > 25]

# Calculate win percentage for filtered teams
filtered['Win_Percentage'] = (filtered['Won_17'] + filtered['Won_18']) / (filtered['Matches_17'] + filtered['Matches_18']) * 100

# Identify the team with the highest win percentage
highest_win_percentage_team = filtered.loc[filtered['Win_Percentage'].idxmax()]

highest_win_percentage_team.head()
# Out:
# C:\Users\Nehul Bawnekar\AppData\Local\Temp\ipykernel_26524\1944283352.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['Win_Percentage'] = (filtered['Won_17'] + filtered['Won_18']) / (filtered['Matches_17'] + filtered['Matches_18']) * 100
# Team          SRH
# Matches_17     14
# Won_17          8
# Lost_17         5
# Tied_17         0
# Name: 1, dtype: object
