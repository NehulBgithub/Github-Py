# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
# series -> A series is a column
# dataframe -> A dataframe is a two dimensional data structure i.e. data is aligned in as tabular fashion in rows and columns

# %%
firts_series=pd.Series(["a","b","c","d"])

# %%
print(firts_series)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
print(type(firts_series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
firts_series=pd.Series(["a","b","c","d"],index=[4,5,6,7],name="First")

# %%
print(firts_series)
# Out:
# 4    a
# 5    b
# 6    c
# 7    d
# Name: First, dtype: object

# %%
# print(firts_series[0])
print(firts_series[4])
# Out:
# a

# %%
firts_series=pd.Series([1,2,3,4,"a"],index=[4,5,6,7,8],name="First")

# %%
print(firts_series)
# Out:
# 4    1
# 5    2
# 6    3
# 7    4
# 8    a
# Name: First, dtype: object

# %%
import numpy as np

# %%
array_2d=np.random.randint(1,10,(3,4))

# %%
array_2d
# Out:
# array([[9, 1, 9, 5],
#        [5, 8, 4, 6],
#        [7, 4, 2, 3]])

# %%
import pandas as pd
pd.DataFrame(array_2d)
# Out:
#    0  1  2  3
# 0  9  1  9  5
# 1  5  8  4  6
# 2  7  4  2  3

# %%
first_df
# Out:
#    0  1  2  3
# 0  5  5  7  3
# 1  3  2  9  5
# 2  5  9  8  3

# %%
type(first_df)
# Out:
# pandas.core.frame.DataFrame

# %%
first_df=pd.DataFrame(array_2d,columns=["a","b","c","d"])

# %%
first_df
# Out:
#    a  b  c  d
# 0  5  5  7  3
# 1  3  2  9  5
# 2  5  9  8  3

# %%
first_df=pd.DataFrame(array_2d,columns=["a","b","c","d"],index=['First','Second',"Third"])

# %%
first_df
# Out:
#         a  b  c  d
# First   5  5  7  3
# Second  3  2  9  5
# Third   5  9  8  3

# %%
df_using_list_of_lists=[["Amar",10],["Akbar",20],["Anthony",30]]
df=pd.DataFrame(df_using_list_of_lists,columns=["Name","Age"])

# %%
df
# Out:
#       Name  Age
# 0     Amar   10
# 1    Akbar   20
# 2  Anthony   30

# %%
df_using_dict={"Name":["Amar","Akbar","Anthony"],"Income":[100000,70000,80000]}

# %%
df_using_dict
# Out:
# {'Name': ['Amar', 'Akbar', 'Anthony'], 'Income': [100000, 70000, 80000]}

# %%
df=pd.DataFrame(df_using_dict)

# %%
df
# Out:
#       Name  Income
# 0     Amar  100000
# 1    Akbar   70000
# 2  Anthony   80000

# %%
sries_d={"col1":pd.Series([1,2,3,4]),
        "col2": pd.Series([1,2,3,4])}

# %%
sries_d
# Out:
# {'col1': 0    1
#  1    2
#  2    3
#  3    4
#  dtype: int64,
#  'col2': 0    1
#  1    2
#  2    3
#  3    4
#  dtype: int64}

# %%
df=pd.DataFrame(sries_d)

# %%
df
# Out:
#    col1  col2
# 0     1     1
# 1     2     2
# 2     3     3
# 3     4     4

# %%
lists_of_dict=[{'a':1,'b':2,'c':3},{'a':10,'b':20,'c':30}]

# %%
df=pd.DataFrame(lists_of_dict)

# %%
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
lists_of_dict=[{'b':2,'c':3},{'a':10,'b':20,'c':30},{'a':1,'c':3},{'a':1,'b':2}]

# %%
df=pd.DataFrame(lists_of_dict)

# %%
df
# Out:
#       b     c     a
# 0   2.0   3.0   NaN
# 1  20.0  30.0  10.0
# 2   NaN   3.0   1.0
# 3   2.0   NaN   1.0

# %%
state=["Haryana","Maharastra","UP","Goa"]
capital=["Chandigarh","Mumbai","Lucknow",np.nan]
list_of_tuples=list(zip(state,capital))

# %%
list_of_tuples
# Out:
# [('Haryana', 'Chandigarh'),
#  ('Maharastra', 'Mumbai'),
#  ('UP', 'Lucknow'),
#  ('Goa', nan)]

# %%
df=pd.DataFrame(list_of_tuples,columns=["State","Capital"])

# %%
df
# Out:
#         State     Capital
# 0     Haryana  Chandigarh
# 1  Maharastra      Mumbai
# 2          UP     Lucknow
# 3         Goa         NaN

# %%
list(df.index)
# Out:
# [0, 1, 2, 3]

# %%
big_array=np.random.randint(1,10,(100,5))

# %%
df=pd.DataFrame(big_array,columns=['A','B','C','D','E'])

# %%
df
# Out:
#     A  B  C  D  E
# 0   3  4  1  1  5
# 1   7  1  3  7  2
# 2   9  1  2  9  3
# 3   1  7  6  5  2
# 4   7  7  2  9  5
# .. .. .. .. .. ..
# 95  5  3  9  1  7
# 96  7  1  1  8  4
# 97  6  5  9  8  3
# 98  1  3  6  6  9
# 99  8  6  4  4  6
#
# [100 rows x 5 columns]

# %%
# this shows how to create dataframe into csv
df.to_csv("random_val.csv")

# %%
df.head()
# Out:
#    A  B  C  D  E
# 0  3  4  1  1  5
# 1  7  1  3  7  2
# 2  9  1  2  9  3
# 3  1  7  6  5  2
# 4  7  7  2  9  5

# %%
df.tail()
# Out:
#     A  B  C  D  E
# 95  5  3  9  1  7
# 96  7  1  1  8  4
# 97  6  5  9  8  3
# 98  1  3  6  6  9
# 99  8  6  4  4  6

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    int32
#  1   B       100 non-null    int32
#  2   C       100 non-null    int32
#  3   D       100 non-null    int32
#  4   E       100 non-null    int32
# dtypes: int32(5)
# memory usage: 2.1 KB

# %%
df.rename(columns={"A":"a","B":"b","C":"c","D":"d","E":"e"})
# Out:
#     a  b  c  d  e
# 0   3  4  1  1  5
# 1   7  1  3  7  2
# 2   9  1  2  9  3
# 3   1  7  6  5  2
# 4   7  7  2  9  5
# .. .. .. .. .. ..
# 95  5  3  9  1  7
# 96  7  1  1  8  4
# 97  6  5  9  8  3
# 98  1  3  6  6  9
# 99  8  6  4  4  6
#
# [100 rows x 5 columns]

# %%
df
# Out:
#     A  B  C  D  E
# 0   3  4  1  1  5
# 1   7  1  3  7  2
# 2   9  1  2  9  3
# 3   1  7  6  5  2
# 4   7  7  2  9  5
# .. .. .. .. .. ..
# 95  5  3  9  1  7
# 96  7  1  1  8  4
# 97  6  5  9  8  3
# 98  1  3  6  6  9
# 99  8  6  4  4  6
#
# [100 rows x 5 columns]

# %%
df.rename(columns={"A":"a","B":"b","C":"c","D":"d","E":"e"},inplace=True)

# %%
df
# Out:
#     a  b  c  d  e
# 0   3  4  1  1  5
# 1   7  1  3  7  2
# 2   9  1  2  9  3
# 3   1  7  6  5  2
# 4   7  7  2  9  5
# .. .. .. .. .. ..
# 95  5  3  9  1  7
# 96  7  1  1  8  4
# 97  6  5  9  8  3
# 98  1  3  6  6  9
# 99  8  6  4  4  6
#
# [100 rows x 5 columns]

# %%
df.shape
# Out:
# (100, 5)

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("imdb_data.csv")

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.shape
# Out:
# (3000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3000 non-null   int64
#  1   id                     3000 non-null   int64
#  2   belongs_to_collection  604 non-null    object
#  3   budget                 3000 non-null   int64
#  4   genres                 2993 non-null   object
#  5   homepage               946 non-null    object
#  6   imdb_id                3000 non-null   object
#  7   original_language      3000 non-null   object
#  8   original_title         3000 non-null   object
#  9   overview               2992 non-null   object
#  10  popularity             3000 non-null   float64
#  11  poster_path            2999 non-null   object
#  12  production_companies   2844 non-null   object
#  13  production_countries   2945 non-null   object
# ...

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
df.describe()
# Out:
#         Unnamed: 0           id        budget   popularity      runtime  \
# count  3000.000000  3000.000000  3.000000e+03  3000.000000  2998.000000
# mean   1499.500000  1500.500000  2.253133e+07     8.463274   107.856571
# std     866.169729   866.169729  3.702609e+07    12.104000    22.086434
# min       0.000000     1.000000  0.000000e+00     0.000001     0.000000
# 25%     749.750000   750.750000  0.000000e+00     4.018053    94.000000
# 50%    1499.500000  1500.500000  8.000000e+06     7.374861   104.000000
# 75%    2249.250000  2250.250000  2.900000e+07    10.890983   118.000000
# max    2999.000000  3000.000000  3.800000e+08   294.337037   338.000000
#
#             revenue
# count  3.000000e+03
# mean   6.672585e+07
# std    1.375323e+08
# min    1.000000e+00
# 25%    2.379808e+06
# 50%    1.680707e+07
# 75%    6.891920e+07
# max    1.519558e+09

# %% [markdown]
# # Indexing and Slicing

# %%
df.head()
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                NaN
# 3           3   4                                                NaN
# 4           4   5                                                NaN
#
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# ...

# %% [markdown]
# # loc and iloc

# %%
df.iloc[:,-3:]
# Out:
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# ...

# %%
df.iloc[:5,:5]
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                NaN
# 3           3   4                                                NaN
# 4           4   5                                                NaN
#
#      budget                                             genres
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...

# %%
df.loc[30:40,['homepage','original_language']]
# Out:
#                                              homepage original_language
# 30                                                NaN                fr
# 31                        http://www.cache-derfilm.at                fr
# 32               http://www.thelastwitchhunter.movie/                en
# 33                                                NaN                en
# 34                                                NaN                en
# 35                        http://www.safethefilm.com/                en
# 36                                                NaN                en
# 37                                                NaN                en
# 38                         http://www.watchfinal.com/                en
# 39                                                NaN                en
# 40  http://www.magpictures.com/profile.aspx?id=983...                en

# %%
df.loc[:]
# Out:
#       Unnamed: 0    id                              belongs_to_collection  \
# 0              0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1              1     2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2              2     3                                                NaN
# 3              3     4                                                NaN
# 4              4     5                                                NaN
# ...          ...   ...                                                ...
# 2995        2995  2996                                                NaN
# 2996        2996  2997                                                NaN
# 2997        2997  2998                                                NaN
# 2998        2998  2999                                                NaN
# 2999        2999  3000                                                NaN
#
#         budget                                             genres  \
# ...

# %% [markdown]
# # Boolean indexing on a dataframe

# %%
df['original_language']=='en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
eng_movie=df[df['original_language']=="en"]

# %%
eng_movie
# Out:
#       Unnamed: 0    id                              belongs_to_collection  \
# 0              0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1              1     2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2              2     3                                                NaN
# 5              5     6                                                NaN
# 6              6     7                                                NaN
# ...          ...   ...                                                ...
# 2994        2994  2995                                                NaN
# 2995        2995  2996                                                NaN
# 2997        2997  2998                                                NaN
# 2998        2998  2999                                                NaN
# 2999        2999  3000                                                NaN
#
#         budget                                             genres  \
# ...

# %%
eng_movie.shape
# Out:
# (2575, 24)

# %%
long_movies=df[df['runtime']>120]

# %%
long_movies
# Out:
#       Unnamed: 0    id                              belongs_to_collection  \
# 3              3     4                                                NaN
# 12            12    13                                                NaN
# 14            14    15                                                NaN
# 20            20    21                                                NaN
# 33            33    34  [{'id': 207632, 'name': 'The ABCs of Death Col...
# ...          ...   ...                                                ...
# 2969        2969  2970                                                NaN
# 2970        2970  2971                                                NaN
# 2980        2980  2981                                                NaN
# 2992        2992  2993                                                NaN
# 2993        2993  2994                                                NaN
#
#          budget                                             genres  \
# ...

# %%
long_movies[["original_title","budget"]]
# Out:
#            original_title     budget
# 3                 Kahaani    1200000
# 12        American Beauty   15000000
# 14        Minority Report  102000000
# 20          Lost in Space   80000000
# 33        ABCs of Death 2          0
# ...                   ...        ...
# 2969         Gosford Park   19800000
# 2970        The Bodyguard   25000000
# 2980      ആക്ഷൻ ഹീറോ ബിജു     300000
# 2992  The Thief of Bagdad    1135654
# 2993         The Terminal   60000000
#
# [657 rows x 2 columns]

# %%
long_eng_movies=df[(df['original_language']=="en") & (df['runtime']>120)]

# %%
long_eng_movies
# Out:
#       Unnamed: 0    id                              belongs_to_collection  \
# 12            12    13                                                NaN
# 14            14    15                                                NaN
# 20            20    21                                                NaN
# 33            33    34  [{'id': 207632, 'name': 'The ABCs of Death Col...
# 37            37    38                                                NaN
# ...          ...   ...                                                ...
# 2967        2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...
# 2969        2969  2970                                                NaN
# 2970        2970  2971                                                NaN
# 2992        2992  2993                                                NaN
# 2993        2993  2994                                                NaN
#
#          budget                                             genres  \
# ...

# %%
df.shape
# Out:
# (3000, 24)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['half_runtime']=df['runtime']*0.5

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime'],
#       dtype='object')

# %%
df['movie_profit']=df['revenue']-df['budget']

# %%
df.drop(['half_runtime'],axis=1)
# Out:
#       Unnamed: 0    id                              belongs_to_collection  \
# 0              0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1              1     2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2              2     3                                                NaN
# 3              3     4                                                NaN
# 4              4     5                                                NaN
# ...          ...   ...                                                ...
# 2995        2995  2996                                                NaN
# 2996        2996  2997                                                NaN
# 2997        2997  2998                                                NaN
# 2998        2998  2999                                                NaN
# 2999        2999  3000                                                NaN
#
#         budget                                             genres  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime', 'movie_profit'],
#       dtype='object')

# %%
df.drop(['half_runtime'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'movie_profit'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0    id                              belongs_to_collection  \
# 0              0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1              1     2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2              2     3                                                NaN
# 3              3     4                                                NaN
# 4              4     5                                                NaN
# ...          ...   ...                                                ...
# 2995        2995  2996                                                NaN
# 2996        2996  2997                                                NaN
# 2997        2997  2998                                                NaN
# 2998        2998  2999                                                NaN
# 2999        2999  3000                                                NaN
#
#         budget                                             genres  \
# ...

# %%
df.set_index('id',inplace=True)

# %%
df
# Out:
#       Unnamed: 0                              belongs_to_collection    budget  \
# id
# 1              0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2              1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 3              2                                                NaN   3300000
# 4              3                                                NaN   1200000
# 5              4                                                NaN         0
# ...          ...                                                ...       ...
# 2996        2995                                                NaN         0
# 2997        2996                                                NaN         0
# 2998        2997                                                NaN  65000000
# 2999        2998                                                NaN  42000000
# 3000        2999                                                NaN  35000000
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'movie_profit'],
#       dtype='object')

# %%
df['runtime'].sum()
# Out:
# 323354.0

# %%
df['runtime'].min()
# Out:
# 0.0

# %%
df['runtime'].max()
# Out:
# 338.0

# %%
df[df['runtime']==0.0]
# Out:
#       Unnamed: 0                              belongs_to_collection    budget  \
# id
# 391          390                                                NaN   6843500
# 592          591                                                NaN         0
# 925          924                                                NaN         0
# 978          977                                                NaN  11000000
# 1256        1255                                                NaN         0
# 1542        1541                                                NaN    750000
# 1875        1874                                                NaN         0
# 2151        2150                                                NaN   5000000
# 2499        2498  [{'id': 106790, 'name': 'Hooked Collection', '...   3500000
# 2646        2645                                                NaN         0
# 2786        2785                                                NaN         0
# ...

# %%
def convert_to_ucase(column):
    return column.upper()

# %%
df["title"]=df['title'].apply(convert_to_ucase)

# %%
df
# Out:
#       Unnamed: 0                              belongs_to_collection    budget  \
# id
# 1              0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2              1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 3              2                                                NaN   3300000
# 4              3                                                NaN   1200000
# 5              4                                                NaN         0
# ...          ...                                                ...       ...
# 2996        2995                                                NaN         0
# 2997        2996                                                NaN         0
# 2998        2997                                                NaN  65000000
# 2999        2998                                                NaN  42000000
# 3000        2999                                                NaN  35000000
#
# ...

# %%
df[['belongs_to_collection','budget','genres','homepage','imdb_id','original_language','original_title','overview','popularity','runtime']].sort_values('runtime',ascending=True)
# Out:
#                                   belongs_to_collection    budget  \
# id
# 2786                                                NaN         0
# 2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# 2646                                                NaN         0
# 592                                                 NaN         0
# 391                                                 NaN   6843500
# ...                                                 ...       ...
# 524                                                 NaN  13000000
# 1923                                                NaN  31115000
# 1212                                                NaN  18000000
# 1336                                                NaN   6000000
# 2303                                                NaN         0
#
#                                                  genres homepage    imdb_id  \
# id
# 2786  [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...      NaN  tt0278675
# ...

# %%
df[['belongs_to_collection','budget','genres','homepage','imdb_id','original_language','original_title','overview','popularity','runtime']].sort_values(['runtime','budget'],ascending=[True,False])
# Out:
#                                   belongs_to_collection    budget  \
# id
# 978                                                 NaN  11000000
# 391                                                 NaN   6843500
# 2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# 2151                                                NaN   5000000
# 2499  [{'id': 106790, 'name': 'Hooked Collection', '...   3500000
# ...                                                 ...       ...
# 524                                                 NaN  13000000
# 1923                                                NaN  31115000
# 1212                                                NaN  18000000
# 1336                                                NaN   6000000
# 2303                                                NaN         0
#
#                                                  genres homepage    imdb_id  \
# id
# 978                      [{'id': 35, 'name': 'Comedy'}]      NaN  tt2076251
# ...

# %% [markdown]
# # DateTime functions

# %%
df.head()
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                NaN
# 3           3   4                                                NaN
# 4           4   5                                                NaN
#
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# ...

# %%
df.set_index('imdb_id',inplace=True)

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: object

# %%
from datetime import datetime
from datetime import date

# %%
# 03/17/2024
# 03/17/2024:15:00:00

# %%
# strptime: it means string parser, this will convert a string format into datetime
# strftime: it means string formatter, this will format datetime object into string format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3000 non-null   int64
#  1   id                     3000 non-null   int64
#  2   belongs_to_collection  604 non-null    object
#  3   budget                 3000 non-null   int64
#  4   genres                 2993 non-null   object
#  5   homepage               946 non-null    object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['new_release_date']=df['release_date'].apply(lambda x:datetime.strptime(x,'%m/%d/%y'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3000 non-null   int64
#  1   id                     3000 non-null   int64
#  2   belongs_to_collection  604 non-null    object
#  3   budget                 3000 non-null   int64
#  4   genres                 2993 non-null   object
#  5   homepage               946 non-null    object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['new_release_date'][0].day
# Out:
# 20

# %%
print(date.today())
# Out:
# 2024-03-17

# %%
print(datetime.now())
# Out:
# 2024-03-17 14:32:44.819930

# %%
from datetime import timedelta

# %%
print(date.today())
# Out:
# 2024-03-17

# %%
print(date.today()+timedelta(days=8))
# Out:
# 2024-03-25

# %%
print(datetime.now()+timedelta(seconds=6))
# Out:
# 2024-03-17 14:38:46.802600

# %%
# unique()
# nunique()
# value_counts()
# isnull()
# fillna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3000 non-null   int64
#  1   id                     3000 non-null   int64
#  2   belongs_to_collection  604 non-null    object
#  3   budget                 3000 non-null   int64
#  4   genres                 2993 non-null   object
#  5   homepage               946 non-null    object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
list(df['status'].unique())
# Out:
# ['Released', 'Rumored']

# %%
list(df['original_language'].unique())
# Out:
# ['en',
#  'hi',
#  'ko',
#  'sr',
#  'fr',
#  'it',
#  'nl',
#  'zh',
#  'es',
#  'cs',
#  'ta',
#  'cn',
#  'ru',
#  'tr',
#  'ja',
#  'fa',
#  'sv',
#  'de',
#  'te',
#  'pt',
#  'mr',
#  'da',
#  'fi',
#  'el',
#  'ur',
#  'he',
#  'no',
#  'ar',
#  'nb',
#  'ro',
#  'vi',
#  'pl',
#  'hu',
#  'ml',
#  'bn',
#  'id']

# %%
df.status.nunique()
# Out:
# 2

# %%
df.original_language.nunique()
# Out:
# 36

# %%
df.status.value_counts()
# Out:
# status
# Released    2996
# Rumored        4
# Name: count, dtype: int64

# %%
df.original_language.value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#            Unnamed: 0  id                              belongs_to_collection  \
# imdb_id
# tt2637294           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# tt0368933           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# tt2582802           2   3                                                NaN
# tt1821480           3   4                                                NaN
# tt1380152           4   5                                                NaN
#
#              budget                                             genres  \
# imdb_id
# tt2637294  14000000                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802   3300000                      [{'id': 18, 'name': 'Drama'}]
# tt1821480   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
# ...

# %%
df[df['homepage'].isnull()]
# Out:
#            Unnamed: 0    id  \
# imdb_id
# tt2637294           0     1
# tt0368933           1     2
# tt1380152           4     5
# tt0093743           5     6
# tt0391024           7     8
# ...               ...   ...
# tt0015400        2992  2993
# tt0105327        2994  2995
# tt0109403        2995  2996
# tt2364975        2996  2997
# tt0116908        2997  2998
#
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt1380152                                                NaN         0
# tt0093743                                                NaN   8000000
# tt0391024                                                NaN         0
# ...                                                      ...       ...
# tt0015400                                                NaN   1135654
# ...

# %%
df['homepage'].fillna('not present',inplace=True)

# %%
df.head()
# Out:
#            Unnamed: 0  id                              belongs_to_collection  \
# imdb_id
# tt2637294           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# tt0368933           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# tt2582802           2   3                                                NaN
# tt1821480           3   4                                                NaN
# tt1380152           4   5                                                NaN
#
#              budget                                             genres  \
# imdb_id
# tt2637294  14000000                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802   3300000                      [{'id': 18, 'name': 'Drama'}]
# tt1821480   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3000 non-null   int64
#  1   id                     3000 non-null   int64
#  2   belongs_to_collection  604 non-null    object
#  3   budget                 3000 non-null   int64
#  4   genres                 2993 non-null   object
#  5   homepage               3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                    0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# new_release_date            0
# dtype: int64

# %%
df.shape
# Out:
# (3000, 24)

# %%
fillna()=> it will replace null values with desired value
dropna()=> it will drop null values

# %%
df['cast'].dropna()
# Out:
# imdb_id
# tt2637294    [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# tt0368933    [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# tt2582802    [{'cast_id': 5, 'character': 'Andrew Neimann',...
# tt1821480    [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# tt1380152    [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#                                    ...
# tt0109403    [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# tt2364975    [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# tt0116908    [{'cast_id': 10, 'character': 'Samantha Caine ...
# tt0343135    [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# tt1600195    [{'cast_id': 2, 'character': 'Nathan Harper', ...
# Name: cast, Length: 2987, dtype: object

# %%
# concatenation
# joins 
# gruopby
